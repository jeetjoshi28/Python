# %% [markdown]
# Conditions Statements (if, elif, else)
# In this section
#     1. Introduction to conditional statements
#     2. if statement
#     3. else statement
#     4. elif statement
#     5. Nested conditional statements
#     6. Common Errors and Best precticesyah

# %%
#if the condition is true, execute the block of code

age = 25
if age > 20:
    print("You are an adult.")
# Out:
# You are an adult.

# %%
# else 
# The else statement executes a block of code if the condition in the if statement is flase.
age = 26

if(age>=18):
    print("you are eligible for voting")
else:
    print("you are not eligible for voting")
# Out:
# you are eligible for voting

# %%
# elif statements
# The elif statement allows you to check multipal conditions. If stands for "else if"

age = 15
if age < 13:
    print("You are a clild")
elif age < 18:
    print("You are a teenager")
else:
    print("You are an adult")
# Out:
# You are a teenager

# %%
# Nested Conditional statements
# You can place one or more if, elif, or else statements inside another if, elif, or else statement to create nested conditional statements.

# Number even, odd, negative
num= int(input("Enter the number"))

if num > 0 :
    print("The number is positive")
    if num %2 == 0:
        print("The number is even")
    else:
        print("The number is odd")
else:
    print("The number is zero or negative")
# Out:
# Enter the number 10
# The number is positive
# The number is even

# %%
# practical example 
# year is leap year or not

year = int(input("Enter the year"))

if year % 4 == 0:
    if year%100 == 0:
        if year % 400 == 0:
            print("Is a leap year")
        else:
            print(year, "is not a leap  year")
    else:
        print(year,"is a leap year")

else:
    print(year,"is a not a leap year")
# Out:
# Enter the year 2024
# 2024 is a leap year

# %%
# Assignment 
# Simple calculator program
num1 = float(input("Enter frist number: "))
num2 = float(input("Enter second number: "))
operation = input("Enter operation (+, -, *, /): ")

# Perform the requested operation

if operation == '+':
    result = num1 + num2

elif operation == '-':
    result = num1 - num2

elif operation == '*':
    result = num1 * num2

elif operation == '/':
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error! Division by zero."
else:
    result = "Invalid operation."

print("Result:", result)
# Out:
# Enter frist number:  10
# Enter second number:  5
# Enter operation (+, -, *, /):  /
# Result: 2.0
